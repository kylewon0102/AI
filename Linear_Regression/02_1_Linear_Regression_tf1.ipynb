# %%
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()

a = tf.constant(7.0, name = 'data1')
b = tf.constant(3.0, name = 'data2')
c = tf.constant(2.0, name = 'data3')

v = a * b / c

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    print(sess.run(v))
# Out:
# 10.5

# %%
#tf version2 
"""
import tensorflow as tf

a = tf.constant(7.0, name = 'data1')
b = tf.constant(3.0, name = 'data2')
c = tf.constant(2.0, name = 'data3')

v = a * b / c

print(v)
print(v.numpy())
"""
# Out:
# "\nimport tensorflow as tf\n\na = tf.constant(7.0, name = 'data1')\nb = tf.constant(3.0, name = 'data2')\nc = tf.constant(2.0, name = 'data3')\n\nv = a * b / c\n\nprint(v)\nprint(v.numpy())\n"

# %% [markdown]
# <img src="attachment:86532b58-ac86-41b3-a16b-e637887e53e0.png" width="50%">
# <img src="attachment:0943bbb0-3a7e-45fd-9f9e-3172604351b3.png" width="50%">
# <img src="attachment:634241f7-994f-45b7-ae83-9621f2ee66c3.png" width="50%">
# <img src="attachment:ccb3b709-a77a-4abd-a40d-e1851e40fed5.png" width="50%">
# <img src="attachment:593caa51-9c96-4fcc-95c3-25fb4f20b4b3.png" width="50%">
# <img src="attachment:65e2d8c7-96c5-4731-8eb5-21fede980e5b.png" width="50%">

# %%
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_v2_behavior()

data = [[2,81], [4, 93], [6, 91], [8, 97]]
#data = [[1, 0.2], [2, 0.3], [3, 0.5], [4, 0.6], [5, 0.9], [6, 0.95], [7, 1.1], [8, 1.5]]
x_data = [x_row[0] for x_row in data]
y_data = [y_row[1] for y_row in data]

#임의의 a 와 b 값
#기울기는 0~10 사이 b는 0~100 사이 
a = tf.Variable(tf.random_uniform([1], 0, 10, dtype = tf.float64, seed=0))
b = tf.Variable(tf.random_uniform([1], 0, 100, dtype = tf.float64, seed=0))

y = a*x_data+b

rmse = tf.sqrt(tf.reduce_mean(tf.square(y-y_data)))
learning_rate = 0.1

gradient_descent = tf.train.GradientDescentOptimizer(learning_rate).minimize(rmse)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    for step in range(2001):
        sess.run(gradient_descent)
        if step %100 == 0:
            print("Epoch: %.f, RMSE = %.04f, slope a = %.4f, y-intercept b = %.4f" % (step, sess.run(rmse), sess.run(a), sess.run(b)))
# Out:
# Epoch: 0, RMSE = 30.2139, slope a = 7.5235, y-intercept b = 80.5984
# Epoch: 100, RMSE = 2.8860, slope a = 2.2299, y-intercept b = 79.4181
# Epoch: 200, RMSE = 2.8826, slope a = 2.2601, y-intercept b = 79.2379
# Epoch: 300, RMSE = 2.8815, slope a = 2.2773, y-intercept b = 79.1353
# Epoch: 400, RMSE = 2.8811, slope a = 2.2871, y-intercept b = 79.0770
# Epoch: 500, RMSE = 2.8810, slope a = 2.2927, y-intercept b = 79.0438
# Epoch: 600, RMSE = 2.8810, slope a = 2.2958, y-intercept b = 79.0249
# Epoch: 700, RMSE = 2.8810, slope a = 2.2976, y-intercept b = 79.0142
# Epoch: 800, RMSE = 2.8810, slope a = 2.2987, y-intercept b = 79.0081
# Epoch: 900, RMSE = 2.8810, slope a = 2.2992, y-intercept b = 79.0046
# Epoch: 1000, RMSE = 2.8810, slope a = 2.2996, y-intercept b = 79.0026
# Epoch: 1100, RMSE = 2.8810, slope a = 2.2998, y-intercept b = 79.0015
# Epoch: 1200, RMSE = 2.8810, slope a = 2.2999, y-intercept b = 79.0008
# Epoch: 1300, RMSE = 2.8810, slope a = 2.2999, y-intercept b = 79.0005
# ...

# %% [markdown]
# <img src="attachment:e2ab3999-7341-4ca0-bd5b-c4debdeb9fca.png" width="50%">

# %%
import tensorflow.compat.v1 as tf
tf.compat.v1.disable_v2_behavior()

#data = [[2,81], [4, 93], [6, 91], [8, 97]]
data = [[1, 0.2], [2, 0.3], [3, 0.5], [4, 0.6], [5, 0.9], [6, 0.95], [7, 1.1], [8, 1.5]]
x_data = [x_row[0] for x_row in data]
y_data = [y_row[1] for y_row in data]

#temporary a and b
#slope btw 0~10, b btw 0~100 사이 
a = tf.Variable(tf.random_uniform([1], 0, 10, dtype = tf.float64, seed=0))
b = tf.Variable(tf.random_uniform([1], 0, 100, dtype = tf.float64, seed=0))

y = a*x_data+b

rmse = tf.sqrt(tf.reduce_mean(tf.square(y-y_data)))
learning_rate = 0.001

gradient_descent = tf.train.GradientDescentOptimizer(learning_rate).minimize(rmse)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    for step in range(200001):
        sess.run(gradient_descent)
        if step %5000 == 0:
            print("Epoch: %.f, RMSE = %.04f, slope a = %.4f, y-intercept b = %.4f" % (step, sess.run(rmse), sess.run(a), sess.run(b)))
# Out:
# Epoch: 0, RMSE = 117.6190, slope a = 8.0642, y-intercept b = 80.6891
# /var/folders/x5/47g9ybwn3dj2qvmd4l8th0x80000gn/T/ipykernel_3161/1251088053.py:27: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   print("Epoch: %.f, RMSE = %.04f, slope a = %.4f, y-intercept b = %.4f" % (step, sess.run(rmse), sess.run(a), sess.run(b)))
# Epoch: 5000, RMSE = 36.3937, slope a = -10.9394, y-intercept b = 75.9815
# Epoch: 10000, RMSE = 33.3184, slope a = -12.8338, y-intercept b = 73.3939
# Epoch: 15000, RMSE = 32.3194, slope a = -12.4909, y-intercept b = 71.1859
# Epoch: 20000, RMSE = 31.3213, slope a = -12.1005, y-intercept b = 68.9863
# Epoch: 25000, RMSE = 30.3232, slope a = -11.7094, y-intercept b = 66.7869
# Epoch: 30000, RMSE = 29.3251, slope a = -11.3182, y-intercept b = 64.5875
# ...
